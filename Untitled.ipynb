# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import statistics
import h5py

#this sets the size of the plot to something useful
plt.rcParams["figure.figsize"] = (20,15)

# %%
hf = h5py.File('gammaray_lab4.h5', 'r')

# %%
hf.keys()
# Out:
# <KeysViewHDF5 ['data']>

# %%
data = np.array(hf.get('data'))

# %%
#data[:,10000000]

# %%
hf.close()

# %%
len(data[0])
# Out:
# 25920001

# %% [markdown]
# time (in gps seconds)
#
# Solar phase (deg) showing the position of the sun relative to the orbit,
#
# Earth longitude (deg) giving the position of the spacecraft relative to the ground
#
# and particle counts

# %%
fig, ax = plt.subplots(1, 1)
time = 10000+np.array(range(0,60*60*24*2))
#plt.plot(data[0,time],data[1,time])
plt.plot(data[0,time],data[2,time])
plt.plot(data[0,time],data[3,time]*10)

# %%
data[0,len(data[0])-1]
# Out:
# 943272016.0

# %%
time = 10+np.array(range(0,60*60*24*2))

# %%
plt.rcParams["figure.figsize"] = (20,10)

fig, ax = plt.subplots(1, 2)
c = data[3]
a1=314
a2=330
ax[0].hist(c[(data[2] > a1) & (data[2] < a1+1)], 100, density=True)
ax[1].hist(c[(data[2] > a2) & (data[2] < a2+1)], 100, density=True)
plt.show()

# %%
dtheta = 1
thetas = np.arange(0,360,dtheta)
count1 = np.zeros(len(thetas))
for i in range(0,len(thetas)):
    theta = thetas[i]
    count1[i] = statistics.mean(data[3][(data[1] > theta) & (data[1] < theta + dtheta)])

# %%
plt.rcParams["figure.figsize"] = (10,10)
fig, ax = plt.subplots(1, 1)
ax.plot(thetas, count1)

# %%
np.linspace(0,360,dtheta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4fc4576773ba> in <module>
# ----> 1 np.linspace(0,360-d,dtheta)
#
# NameError: name 'd' is not defined

# %%
dtheta = 1
thetas = np.arange(0,360,dtheta)
count2 = np.zeros(len(thetas))
for i in range(0,len(thetas)):
    theta = thetas[i]
    count2[i] = statistics.mean(data[3][(data[2] > theta) & (data[2] < theta + dtheta)])

# %%
plt.rcParams["figure.figsize"] = (10,10)
fig, ax = plt.subplots(1, 1)
ax.plot(thetas, count2)
#plt.yscale('log')

# %%
hf = h5py.File('gammaray_lab4.h5', 'r')
hf.keys()
# Out:
# <KeysViewHDF5 ['data']>
